# %% [markdown]
# # **ASSIGNMENT-1**
#
# -Nikhila.V
#
# 21BCE9008
#
# VIT-AP

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1.Create a pandas dataframe with numpy random values

# %%
df=pd.DataFrame(np.random.randint(1,50,size=(4,4)))

# %%
df
# Out:
#     0   1   2   3
# 0  39  15   7  29
# 1  36  15  30   1
# 2  46   9  44  16
# 3  16  17  37  32

# %% [markdown]
# 2.Rename column names

# %%
df.columns=['Random_value 1','Random_value 2','Random_value 3','Random_value 4']
df
# Out:
#    Random_value 1  Random_value 2  Random_value 3  Random_value 4
# 0              39              15               7              29
# 1              36              15              30               1
# 2              46               9              44              16
# 3              16              17              37              32

# %% [markdown]
# 3.Find descriptive statistics of df dataframe.

# %%
df.describe()
# Out:
#        Random_value 1  Random_value 2  Random_value 3  Random_value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        34.250000       14.000000       29.500000       19.500000
# std         12.867919        3.464102       16.051999       14.153916
# min         16.000000        9.000000        7.000000        1.000000
# 25%         31.000000       13.500000       24.250000       12.250000
# 50%         37.500000       15.000000       33.500000       22.500000
# 75%         40.750000       15.500000       38.750000       29.750000
# max         46.000000       17.000000       44.000000       32.000000

# %% [markdown]
# 4.check for null values in dataframe and data type of columns

# %%
df.isnull().any()
# Out:
# Random_value 1    False
# Random_value 2    False
# Random_value 3    False
# Random_value 4    False
# dtype: bool

# %%
df.dtypes
# Out:
# Random_value 1    int64
# Random_value 2    int64
# Random_value 3    int64
# Random_value 4    int64
# dtype: object

# %% [markdown]
# 5.Display the 'Random_value 2'and 'Random_value 3'columns with location and index location method

# %%
df.loc[:,['Random_value 2','Random_value 3']]
# Out:
#    Random_value 2  Random_value 3
# 0              15               7
# 1              15              30
# 2               9              44
# 3              17              37

# %%
df.iloc[:,[1,2]]
# Out:
#    Random_value 2  Random_value 3
# 0              15               7
# 1              15              30
# 2               9              44
# 3              17              37
